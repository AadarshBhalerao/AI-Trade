# %%
#This is a test file

# %%
<!DOCTYPE html>
<html lang="en">

<head>
    <!-- Required meta tags-->
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
    <meta name="description" content="Colorlib Templates">
    <meta name="author" content="Colorlib">
    <meta name="keywords" content="Colorlib Templates">

    <!-- Title Page-->
    <title>Sanity Test - TAM US</title>

    <!-- Font special for pages-->
    <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i,800,800i"
          rel="stylesheet">
    <script type="text/javascript" src="http://code.jquery.com/jquery-1.7.1.min.js"></script>

    <!--<link rel="icon" type="image/x-icon" href="https://github.com/favicon.ico"/>-->
    <link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css"/>

    <!-- Main CSS-->
    <link rel="stylesheet" type="text/css" href="/static/styles/styles2.css">


</head>

<body>


<div class="bg-dark">
    <img class="zycusLogo" src="/static/images/image/Zycus_Logo.jpg" alt="Zycus logo">
</div>

<form action="info_sent" method="POST" enctype="multipart/form-data">
    <div class="page-wrapper bg-dark">
        <div class="wrapper wrapper--w900">
            <div class="card card-6">

                <!--<div class="card-heading">-->
                    <!--<h2 class="title">Sanity Test Application - US TAM</h2>-->
                <!--</div>-->
                <div class="card-body">
                    <form method="POST">

                        <div class="form-row">
                            <div class="name">groupID</div>
                            <div class="value">
                                <input class="subject_input_box" type="text" name="group_id">
                            </div>
                        </div>

                        <div class="form-row">
                            <div class="name">artifactID</div>
                            <div class="value">
                                <input class="subject_input_box" type="text" name="artifact_id">
                            </div>
                        </div>

                        <div class="form-row">
                            <div class="name">version</div>
                            <div class="value">
                                <input class="subject_input_box" type="text" name="version_">
                            </div>
                        </div>

                        <div class="form-row">
                            <div class="name">environment</div>
                            <div>
                                <select name="environment_" id="second-choice">

                                    <option name="environment_" value="higher_nexus_">higher nexus</option>
                                    <option name="environment_" value="lower_nexus_">lower nexus</option>

                                </select></div>

                        </div>
                        <div class="form-row">
                            <div class="name">path</div>
                            <div class="value">
                                <input class="subject_input_box" type="text" name="path_">
                            </div>
                        </div>
                        <h5>Place in GFS location and enter only model zip path here in this format -> "/GFS/models/ABC.zip"</h5>
                    </form>
                </div>
                <div class="card-footer">
                    <button class="btn btn--radius-2 btn--blue-2" type="submit" action="info_sent" onclick="clicked()">
                        Submit
                    </button>
                </div>
            </div>
        </div>
    </div>
</form>

<!-- Jquery JS-->
<script src="static/vendor/jquery/jquery.min.js"></script>
<script type="text/javascript">
        function clicked() {
           if (confirm('Do you want to submit?')) {
               yourformelement.submit();
           } else {
               return false;
           }
        }


</script>
<script>function selectallaccount(source) {
      checkboxes = document.getElementsByName('Account');
      for(var i=0, n=checkboxes.length;i<n;i++) {
        checkboxes[i].selected = source.selected;
      }
    }
</script>
<script>function selectallproduct(source) {
      checkboxes = document.getElementsByName('product');
      for(var i=0, n=checkboxes.length;i<n;i++) {
        checkboxes[i].selected = source.selected;
      }
    }
</script>

<!-- Main JS-->
<script src="static/js/global.js"></script>


</body><!-- This templates was made by Colorlib (https://colorlib.com) -->

</html>
<!-- end document-->
